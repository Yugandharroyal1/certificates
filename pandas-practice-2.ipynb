# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/usa-cities/usa_cities.csv

# %% [markdown]
# # reading

# %%
filepath=("/kaggle/input/usa-cities/usa_cities.csv")
df=pd.read_csv(filepath)
df
# Out:
#              city    city_ascii        lat         lng      pop  \
# 0          Calais        Calais  45.165989  -67.242392   1781.5
# 1         Houlton       Houlton  46.125517  -67.839720   6051.5
# 2    Presque Isle  Presque Isle  46.793409  -68.002165   9466.0
# 3      Bar Harbor    Bar Harbor  44.387897  -68.204375   4483.5
# 4          Bangor        Bangor  44.801153  -68.778345  40843.0
# ..            ...           ...        ...         ...      ...
# 764    Point Hope    Point Hope  68.347726 -166.808020    461.0
# 765         Wales         Wales  65.609599 -168.087503     99.0
# 766      Nikolski      Nikolski  52.938434 -168.867688     18.0
# 767       Gambell       Gambell  63.779710 -171.731079    681.0
# 768          Atka          Atka  52.196490 -174.200489     61.0
#
#                       country iso2 iso3 province  abbr
# 0    United States of America   US  USA    Maine   NaN
# 1    United States of America   US  USA    Maine   NaN
# ...

# %% [markdown]
# # selecting

# %%
df.iloc[2]
# Out:
# city                      Presque Isle
# city_ascii                Presque Isle
# lat                          46.793409
# lng                         -68.002165
# pop                             9466.0
# country       United States of America
# iso2                                US
# iso3                               USA
# province                         Maine
# abbr                               NaN
# Name: 2, dtype: object

# %%
df.iloc[1]
# Out:
# city                           Houlton
# city_ascii                     Houlton
# lat                          46.125517
# lng                          -67.83972
# pop                             6051.5
# country       United States of America
# iso2                                US
# iso3                               USA
# province                         Maine
# abbr                               NaN
# Name: 1, dtype: object

# %%
df
# Out:
#              city    city_ascii        lat         lng      pop  \
# 0          Calais        Calais  45.165989  -67.242392   1781.5
# 1         Houlton       Houlton  46.125517  -67.839720   6051.5
# 2    Presque Isle  Presque Isle  46.793409  -68.002165   9466.0
# 3      Bar Harbor    Bar Harbor  44.387897  -68.204375   4483.5
# 4          Bangor        Bangor  44.801153  -68.778345  40843.0
# ..            ...           ...        ...         ...      ...
# 764    Point Hope    Point Hope  68.347726 -166.808020    461.0
# 765         Wales         Wales  65.609599 -168.087503     99.0
# 766      Nikolski      Nikolski  52.938434 -168.867688     18.0
# 767       Gambell       Gambell  63.779710 -171.731079    681.0
# 768          Atka          Atka  52.196490 -174.200489     61.0
#
#                       country iso2 iso3 province  abbr
# 0    United States of America   US  USA    Maine   NaN
# 1    United States of America   US  USA    Maine   NaN
# ...

# %%
df.head(769)
# Out:
#              city    city_ascii        lat         lng      pop  \
# 0          Calais        Calais  45.165989  -67.242392   1781.5
# 1         Houlton       Houlton  46.125517  -67.839720   6051.5
# 2    Presque Isle  Presque Isle  46.793409  -68.002165   9466.0
# 3      Bar Harbor    Bar Harbor  44.387897  -68.204375   4483.5
# 4          Bangor        Bangor  44.801153  -68.778345  40843.0
# ..            ...           ...        ...         ...      ...
# 764    Point Hope    Point Hope  68.347726 -166.808020    461.0
# 765         Wales         Wales  65.609599 -168.087503     99.0
# 766      Nikolski      Nikolski  52.938434 -168.867688     18.0
# 767       Gambell       Gambell  63.779710 -171.731079    681.0
# 768          Atka          Atka  52.196490 -174.200489     61.0
#
#                       country iso2 iso3 province  abbr
# 0    United States of America   US  USA    Maine   NaN
# 1    United States of America   US  USA    Maine   NaN
# ...

# %%
df.head(12)
# Out:
#             city    city_ascii        lat        lng        pop  \
# 0         Calais        Calais  45.165989 -67.242392     1781.5
# 1        Houlton       Houlton  46.125517 -67.839720     6051.5
# 2   Presque Isle  Presque Isle  46.793409 -68.002165     9466.0
# 3     Bar Harbor    Bar Harbor  44.387897 -68.204375     4483.5
# 4         Bangor        Bangor  44.801153 -68.778345    40843.0
# 5     Waterville    Waterville  44.551892 -69.645785    20529.0
# 6        Augusta       Augusta  44.310563 -69.779989    21301.0
# 7       Lewiston      Lewiston  44.100705 -70.215260    46689.0
# 8       Portland      Portland  43.672162 -70.245527    99504.0
# 9          Salem         Salem  42.522499 -70.883092   188982.0
# 10   New Bedford   New Bedford  41.656125 -70.944698   115082.5
# 11        Boston        Boston  42.329960 -71.070014  2528070.5
#
#                      country iso2 iso3       province  abbr
# 0   United States of America   US  USA          Maine   NaN
# ...

# %%
df.tail(17)
# Out:
#                  city        city_ascii        lat         lng     pop  \
# 752        False Pass        False Pass  54.851211 -163.415023    35.0
# 753            Kotlit            Kotlit  63.034588 -163.553283  1002.0
# 754  Mountain Village  Mountain Village  62.085524 -163.729009   755.0
# 755          Kivalina          Kivalina  67.731492 -164.485903   374.0
# 756           Emmonak           Emmonak  62.776981 -164.522992   100.0
# 757           Tununak           Tununak  60.585487 -165.255789   352.0
# 758              Nome              Nome  64.506100 -165.406374  3021.0
# 759        Shishmaref        Shishmaref  66.256975 -166.071889   254.0
# 760        Hooper Bay        Hooper Bay  61.531088 -166.096565   623.0
# 761          Mekoryuk          Mekoryuk  60.388647 -166.189937    99.0
# 762            Teller            Teller  65.263599 -166.360786    83.0
# 763          Unalaska          Unalaska  53.868584 -166.531603  1938.5
# ...

# %%
df.sample(1)
# Out:
#              city    city_ascii        lat        lng       pop  \
# 137  Jacksonville  Jacksonville  30.330021 -81.669987  904953.5
#
#                       country iso2 iso3 province  abbr
# 137  United States of America   US  USA  Florida   NaN

# %%
df.iloc[111]
# Out:
# city                         Salisbury
# city_ascii                   Salisbury
# lat                           35.67078
# lng                         -80.474478
# pop                            33907.0
# country       United States of America
# iso2                                US
# iso3                               USA
# province                North Carolina
# abbr                               NaN
# Name: 111, dtype: object

# %%
df.loc[1,['city','city_ascii']]
# Out:
# city          Houlton
# city_ascii    Houlton
# Name: 1, dtype: object

# %%
df.iloc[[1,7,8,9,11,2,33,4]]
# Out:
#             city    city_ascii        lat        lng         pop  \
# 1        Houlton       Houlton  46.125517 -67.839720      6051.5
# 7       Lewiston      Lewiston  44.100705 -70.215260     46689.0
# 8       Portland      Portland  43.672162 -70.245527     99504.0
# 9          Salem         Salem  42.522499 -70.883092    188982.0
# 11        Boston        Boston  42.329960 -71.070014   2528070.5
# 2   Presque Isle  Presque Isle  46.793409 -68.002165      9466.0
# 33      New York      New York  40.749979 -73.980017  13524139.0
# 4         Bangor        Bangor  44.801153 -68.778345     40843.0
#
#                      country iso2 iso3       province  abbr
# 1   United States of America   US  USA          Maine   NaN
# 7   United States of America   US  USA          Maine   NaN
# 8   United States of America   US  USA          Maine   NaN
# 9   United States of America   US  USA  Massachusetts   NaN
# 11  United States of America   US  USA  Massachusetts   NaN
# ...

# %%
df.iloc[[3,8,9,0,6,18,9]]
# Out:
#           city  city_ascii        lat        lng       pop  \
# 3   Bar Harbor  Bar Harbor  44.387897 -68.204375    4483.5
# 8     Portland    Portland  43.672162 -70.245527   99504.0
# 9        Salem       Salem  42.522499 -70.883092  188982.0
# 0       Calais      Calais  45.165989 -67.242392    1781.5
# 6      Augusta     Augusta  44.310563 -69.779989   21301.0
# 18  New London  New London  41.355523 -72.100028   61236.0
# 9        Salem       Salem  42.522499 -70.883092  188982.0
#
#                      country iso2 iso3       province  abbr
# 3   United States of America   US  USA          Maine   NaN
# 8   United States of America   US  USA          Maine   NaN
# 9   United States of America   US  USA  Massachusetts   NaN
# 0   United States of America   US  USA          Maine   NaN
# 6   United States of America   US  USA          Maine   NaN
# 18  United States of America   US  USA    Connecticut   NaN
# 9   United States of America   US  USA  Massachusetts   NaN

# %%
df.iloc[1:17]
# Out:
#             city    city_ascii        lat        lng        pop  \
# 1        Houlton       Houlton  46.125517 -67.839720     6051.5
# 2   Presque Isle  Presque Isle  46.793409 -68.002165     9466.0
# 3     Bar Harbor    Bar Harbor  44.387897 -68.204375     4483.5
# 4         Bangor        Bangor  44.801153 -68.778345    40843.0
# 5     Waterville    Waterville  44.551892 -69.645785    20529.0
# 6        Augusta       Augusta  44.310563 -69.779989    21301.0
# 7       Lewiston      Lewiston  44.100705 -70.215260    46689.0
# 8       Portland      Portland  43.672162 -70.245527    99504.0
# 9          Salem         Salem  42.522499 -70.883092   188982.0
# 10   New Bedford   New Bedford  41.656125 -70.944698   115082.5
# 11        Boston        Boston  42.329960 -71.070014  2528070.5
# 12       Newport       Newport  41.490399 -71.313358    35893.0
# 13        Lowell        Lowell  42.633688 -71.316691   415074.0
# 14    Providence    Providence  41.821102 -71.414980   663726.5
# ...

# %%
df.iloc[1:18:2]
# Out:
#           city  city_ascii        lat        lng        pop  \
# 1      Houlton     Houlton  46.125517 -67.839720     6051.5
# 3   Bar Harbor  Bar Harbor  44.387897 -68.204375     4483.5
# 5   Waterville  Waterville  44.551892 -69.645785    20529.0
# 7     Lewiston    Lewiston  44.100705 -70.215260    46689.0
# 9        Salem       Salem  42.522499 -70.883092   188982.0
# 11      Boston      Boston  42.329960 -71.070014  2528070.5
# 13      Lowell      Lowell  42.633688 -71.316691   415074.0
# 15  Manchester  Manchester  42.995992 -71.455287   153221.5
# 17   Worcester   Worcester  42.270429 -71.800021   232290.5
#
#                      country iso2 iso3       province  abbr
# 1   United States of America   US  USA          Maine   NaN
# 3   United States of America   US  USA          Maine   NaN
# 5   United States of America   US  USA          Maine   NaN
# 7   United States of America   US  USA          Maine   NaN
# 9   United States of America   US  USA  Massachusetts   NaN
# ...

# %% [markdown]
# # sorting

# %%
df.sort_values('city',ascending=True)
# Out:
#            city  city_ascii        lat         lng       pop  \
# 440    Aberdeen    Aberdeen  45.465118  -98.486402   24854.0
# 672    Aberdeen    Aberdeen  46.974896 -123.814391   24400.0
# 451     Abilene     Abilene  32.448625  -99.732786  108008.0
# 139       Aiken       Aiken  33.549462  -81.720604   36716.5
# 133       Akron       Akron  41.070399  -81.519996  451155.0
# ..          ...         ...        ...         ...       ...
# 56         York        York  39.962921  -76.728040  128798.5
# 114  Youngstown  Youngstown  41.099699  -80.649739  194765.0
# 637   Yuba City   Yuba City  39.141033 -121.615766   84324.5
# 584        Yuma        Yuma  32.685278 -114.623608   88402.5
# 148  Zanesville  Zanesville  39.940287  -82.013325   32514.0
#
#                       country iso2 iso3        province  abbr
# 440  United States of America   US  USA    South Dakota   NaN
# 672  United States of America   US  USA      Washington   NaN
# ...

# %%
df.sort_values('city_ascii',ascending=True)
# Out:
#            city  city_ascii        lat         lng       pop  \
# 440    Aberdeen    Aberdeen  45.465118  -98.486402   24854.0
# 672    Aberdeen    Aberdeen  46.974896 -123.814391   24400.0
# 451     Abilene     Abilene  32.448625  -99.732786  108008.0
# 139       Aiken       Aiken  33.549462  -81.720604   36716.5
# 133       Akron       Akron  41.070399  -81.519996  451155.0
# ..          ...         ...        ...         ...       ...
# 56         York        York  39.962921  -76.728040  128798.5
# 114  Youngstown  Youngstown  41.099699  -80.649739  194765.0
# 637   Yuba City   Yuba City  39.141033 -121.615766   84324.5
# 584        Yuma        Yuma  32.685278 -114.623608   88402.5
# 148  Zanesville  Zanesville  39.940287  -82.013325   32514.0
#
#                       country iso2 iso3        province  abbr
# 440  United States of America   US  USA    South Dakota   NaN
# 672  United States of America   US  USA      Washington   NaN
# ...

# %%
df.sort_values("lat",ascending=False)
# Out:
#             city   city_ascii        lat         lng       pop  \
# 723       Barrow       Barrow  71.290570 -156.788580    3412.0
# 742   Wainwright   Wainwright  70.636889 -160.038304     174.0
# 727      Atqasuk      Atqasuk  70.469380 -157.395778     201.0
# 697  Prudhoe Bay  Prudhoe Bay  70.292181 -148.669360    2337.0
# 689     Kaktovik     Kaktovik  70.087856 -143.602913     101.0
# ..           ...          ...        ...         ...       ...
# 732      Wahiawa      Wahiawa  21.503092 -158.023621   95336.0
# 731     Honolulu     Honolulu  21.306876 -157.857998  578828.5
# 721      Wailuku      Wailuku  20.891475 -156.504721   32769.5
# 718         Hilo         Hilo  19.699998 -155.090027   47720.5
# 720  Kailua-Kona  Kailua-Kona  19.640556 -155.995556    9870.0
#
#                       country iso2 iso3 province  abbr
# 723  United States of America   US  USA   Alaska   NaN
# 742  United States of America   US  USA   Alaska   NaN
# ...

# %%
idi=df.iloc[20:40:2]
idi
# Out:
#              city     city_ascii        lat        lng        pop  \
# 20    Springfield    Springfield  42.120025 -72.579999   287003.5
# 22      New Haven      New Haven  41.330383 -72.900005   707883.0
# 24     Bridgeport     Bridgeport  41.179979 -73.199961   578545.0
# 26     Pittsfield     Pittsfield  42.448196 -73.259828    45202.0
# 28       Stamford       Stamford  41.053346 -73.539191   434781.5
# 30         Albany         Albany  42.670017 -73.819949   484286.0
# 32    Schenectady    Schenectady  42.814582 -73.939968   104767.5
# 34       Paterson       Paterson  40.919995 -74.170005   151205.0
# 36  Atlantic City  Atlantic City  39.364637 -74.423323    58563.5
# 38   Philadelphia   Philadelphia  39.999973 -75.169996  3504775.0
#
#                      country iso2 iso3       province  abbr
# 20  United States of America   US  USA  Massachusetts   NaN
# 22  United States of America   US  USA    Connecticut   NaN
# ...

# %%
idi.sort_values("pop",ascending=False)
# Out:
#              city     city_ascii        lat        lng        pop  \
# 38   Philadelphia   Philadelphia  39.999973 -75.169996  3504775.0
# 22      New Haven      New Haven  41.330383 -72.900005   707883.0
# 24     Bridgeport     Bridgeport  41.179979 -73.199961   578545.0
# 30         Albany         Albany  42.670017 -73.819949   484286.0
# 28       Stamford       Stamford  41.053346 -73.539191   434781.5
# 20    Springfield    Springfield  42.120025 -72.579999   287003.5
# 34       Paterson       Paterson  40.919995 -74.170005   151205.0
# 32    Schenectady    Schenectady  42.814582 -73.939968   104767.5
# 36  Atlantic City  Atlantic City  39.364637 -74.423323    58563.5
# 26     Pittsfield     Pittsfield  42.448196 -73.259828    45202.0
#
#                      country iso2 iso3       province  abbr
# 38  United States of America   US  USA   Pennsylvania   NaN
# 22  United States of America   US  USA    Connecticut   NaN
# ...

# %%
idi.iloc[1:8:2]
# Out:
#           city  city_ascii        lat        lng       pop  \
# 22   New Haven   New Haven  41.330383 -72.900005  707883.0
# 26  Pittsfield  Pittsfield  42.448196 -73.259828   45202.0
# 30      Albany      Albany  42.670017 -73.819949  484286.0
# 34    Paterson    Paterson  40.919995 -74.170005  151205.0
#
#                      country iso2 iso3       province  abbr
# 22  United States of America   US  USA    Connecticut   NaN
# 26  United States of America   US  USA  Massachusetts   NaN
# 30  United States of America   US  USA       New York   NaN
# 34  United States of America   US  USA     New Jersey   NaN

# %%
df['city']
# Out:
# 0            Calais
# 1           Houlton
# 2      Presque Isle
# 3        Bar Harbor
# 4            Bangor
#            ...
# 764      Point Hope
# 765           Wales
# 766        Nikolski
# 767         Gambell
# 768            Atka
# Name: city, Length: 769, dtype: object

# %%
df.head()
# Out:
#            city    city_ascii        lat        lng      pop  \
# 0        Calais        Calais  45.165989 -67.242392   1781.5
# 1       Houlton       Houlton  46.125517 -67.839720   6051.5
# 2  Presque Isle  Presque Isle  46.793409 -68.002165   9466.0
# 3    Bar Harbor    Bar Harbor  44.387897 -68.204375   4483.5
# 4        Bangor        Bangor  44.801153 -68.778345  40843.0
#
#                     country iso2 iso3 province  abbr
# 0  United States of America   US  USA    Maine   NaN
# 1  United States of America   US  USA    Maine   NaN
# 2  United States of America   US  USA    Maine   NaN
# 3  United States of America   US  USA    Maine   NaN
# 4  United States of America   US  USA    Maine   NaN

# %%
df
# Out:
#              city    city_ascii        lat         lng      pop  \
# 0          Calais        Calais  45.165989  -67.242392   1781.5
# 1         Houlton       Houlton  46.125517  -67.839720   6051.5
# 2    Presque Isle  Presque Isle  46.793409  -68.002165   9466.0
# 3      Bar Harbor    Bar Harbor  44.387897  -68.204375   4483.5
# 4          Bangor        Bangor  44.801153  -68.778345  40843.0
# ..            ...           ...        ...         ...      ...
# 764    Point Hope    Point Hope  68.347726 -166.808020    461.0
# 765         Wales         Wales  65.609599 -168.087503     99.0
# 766      Nikolski      Nikolski  52.938434 -168.867688     18.0
# 767       Gambell       Gambell  63.779710 -171.731079    681.0
# 768          Atka          Atka  52.196490 -174.200489     61.0
#
#                       country iso2 iso3 province  abbr
# 0    United States of America   US  USA    Maine   NaN
# 1    United States of America   US  USA    Maine   NaN
# ...

# %%
df.head(15)
# Out:
#             city    city_ascii        lat        lng        pop  \
# 0         Calais        Calais  45.165989 -67.242392     1781.5
# 1        Houlton       Houlton  46.125517 -67.839720     6051.5
# 2   Presque Isle  Presque Isle  46.793409 -68.002165     9466.0
# 3     Bar Harbor    Bar Harbor  44.387897 -68.204375     4483.5
# 4         Bangor        Bangor  44.801153 -68.778345    40843.0
# 5     Waterville    Waterville  44.551892 -69.645785    20529.0
# 6        Augusta       Augusta  44.310563 -69.779989    21301.0
# 7       Lewiston      Lewiston  44.100705 -70.215260    46689.0
# 8       Portland      Portland  43.672162 -70.245527    99504.0
# 9          Salem         Salem  42.522499 -70.883092   188982.0
# 10   New Bedford   New Bedford  41.656125 -70.944698   115082.5
# 11        Boston        Boston  42.329960 -71.070014  2528070.5
# 12       Newport       Newport  41.490399 -71.313358    35893.0
# 13        Lowell        Lowell  42.633688 -71.316691   415074.0
# ...

# %%
df[(df["province"]=='Maine')&(df['city']=="city_ascii")]
# Out:
# Empty DataFrame
# Columns: [city, city_ascii, lat, lng, pop, country, iso2, iso3, province, abbr]
# Index: []

# %%
df[(df["province"]=='Maine')|(df['city']=="city_ascii")]
# Out:
#            city    city_ascii        lat        lng      pop  \
# 0        Calais        Calais  45.165989 -67.242392   1781.5
# 1       Houlton       Houlton  46.125517 -67.839720   6051.5
# 2  Presque Isle  Presque Isle  46.793409 -68.002165   9466.0
# 3    Bar Harbor    Bar Harbor  44.387897 -68.204375   4483.5
# 4        Bangor        Bangor  44.801153 -68.778345  40843.0
# 5    Waterville    Waterville  44.551892 -69.645785  20529.0
# 6       Augusta       Augusta  44.310563 -69.779989  21301.0
# 7      Lewiston      Lewiston  44.100705 -70.215260  46689.0
# 8      Portland      Portland  43.672162 -70.245527  99504.0
#
#                     country iso2 iso3 province  abbr
# 0  United States of America   US  USA    Maine   NaN
# 1  United States of America   US  USA    Maine   NaN
# 2  United States of America   US  USA    Maine   NaN
# 3  United States of America   US  USA    Maine   NaN
# 4  United States of America   US  USA    Maine   NaN
# ...
